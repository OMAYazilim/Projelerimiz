# %%
import matplotlib.pyplot as mp
import numpy as np
xdegerleri = np.linspace(-2.25, 0.75, 1000)
ydegerleri = np.linspace(-1.5, 1.5, 1000)

xuznlk = len(xdegerleri)
yuznlk = len(ydegerleri)

tekrar_Sayisi = 20
def mandel(c,maxtekrar):
    z = complex(0,0)
    
    for tekrar_sayisi in xrange(maxtekrar):
        z = (z*z)+ c
        
        if abs(z)> 4:
            break
            pass
        pass
    return tekrar_sayisi

atlas = np.empty((xuznlk,yuznlk))
for ix in xrange(xuznlk):
    for iy in xrange(yuznlk):
        
        cx = xdegerleri[ix]
        cy = ydegerleri[iy]
        c = complex(cx,cy)
        
        atlas[ix,iy] = mandel(c,40)
        
        pass
    pass
mp.figure(figsize=(18,18))
mp.imshow(atlas.T, interpolation="nearest")
